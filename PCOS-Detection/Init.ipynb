# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting mlxtend==0.23.3
#   Downloading mlxtend-0.23.3-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.9 MB/s eta 0:00:00
# Collecting imblearn==0.0
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting missingno==0.5.2
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 4)) (1.1.3)
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 10.8 MB/s eta 0:00:00
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 154.2 MB/s eta 0:00:00
# Collecting optuna
#   Downloading optuna-4.2.0-py3-none-any.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 81.1 MB/s eta 0:00:00
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 70.9 MB/s eta 0:00:00
# Collecting xgboost
#   Downloading xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl (223.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.0.0 in /root/venv/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 1)) (3.6.3)
# Requirement already satisfied: scipy>=1.2.1 in /root/venv/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: joblib>=0.13.2 in /root/venv/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: pandas>=0.24.2 in /root/venv/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 1)) (2.1.4)
# Requirement already satisfied: numpy>=1.16.2 in /root/venv/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 1)) (1.25.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 125.1 MB/s eta 0:00:00
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 67.4 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in /root/venv/lib/python3.9/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /root/venv/lib/python3.9/site-packages (from scikit-learn->-r ./requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /root/venv/lib/python3.9/site-packages (from statsmodels->-r ./requirements.txt (line 6)) (24.2)
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 74.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /root/venv/lib/python3.9/site-packages (from optuna->-r ./requirements.txt (line 7)) (4.67.1)
# Collecting colorlog
#   Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: alembic>=1.5.0 in /toolkit-cache/0.2.3/python3.9/kernel-libs/lib/python3.9/site-packages (from optuna->-r ./requirements.txt (line 7)) (1.13.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /toolkit-cache/0.2.3/python3.9/kernel-libs/lib/python3.9/site-packages (from optuna->-r ./requirements.txt (line 7)) (1.4.42)
# Requirement already satisfied: PyYAML in /root/venv/lib/python3.9/site-packages (from optuna->-r ./requirements.txt (line 7)) (6.0.2)
# Collecting et-xmlfile
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Collecting nvidia-nccl-cu12
#   Downloading nvidia_nccl_cu12-2.25.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 MB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: Mako in /toolkit-cache/0.2.3/python3.9/kernel-libs/lib/python3.9/site-packages (from alembic>=1.5.0->optuna->-r ./requirements.txt (line 7)) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /root/venv/lib/python3.9/site-packages (from alembic>=1.5.0->optuna->-r ./requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (4.55.4)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (1.4.7)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: greenlet!=0.4.17 in /toolkit-cache/0.2.3/python3.9/kernel-libs/lib/python3.9/site-packages (from sqlalchemy>=1.4.2->optuna->-r ./requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /root/venv/lib/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna->-r ./requirements.txt (line 7)) (3.0.2)
# Installing collected packages: patsy, nvidia-nccl-cu12, graphviz, et-xmlfile, colorlog, xgboost, scikit-learn, openpyxl, statsmodels, optuna, mlxtend, imbalanced-learn, missingno, imblearn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.3
#     Uninstalling scikit-learn-1.1.3:
#       Successfully uninstalled scikit-learn-1.1.3
# Successfully installed colorlog-6.9.0 et-xmlfile-2.0.0 graphviz-0.20.3 imbalanced-learn-0.12.4 imblearn-0.0 missingno-0.5.2 mlxtend-0.23.3 nvidia-nccl-cu12-2.25.1 openpyxl-3.1.5 optuna-4.2.0 patsy-1.0.1 scikit-learn-1.6.1 statsmodels-0.14.4 xgboost-2.1.4
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=704ca8a1-89c5-4e60-86da-918712a50525' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
